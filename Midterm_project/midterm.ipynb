# %%
pip install pandas requests matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import time
import os
import matplotlib.dates as mdates
from datetime import timedelta
from sklearn.ensemble import RandomForestRegressor

# ==============================
# CONFIG
# ==============================
STATION_WATER_WIND = "9414290"  # San Francisco (Water + Wind)
STATION_CURRENT = "s06010"     # Martinez-AMORCO -Pier (Currents)
DATA_FILE = "ocean_dataset.csv"
UPDATE_INTERVAL = 360 # 6 phút

API_URL = "https://api.tidesandcurrents.noaa.gov/api/prod/datagetter"

# ==============================
# FETCH WATER LEVEL
# ==============================
def fetch_water_level():
    params = {
        "product": "water_level",
        "station": STATION_WATER_WIND,
        "date": "latest",
        "units": "metric",
        "time_zone": "gmt",
        "datum": "MLLW",
        "format": "json"
    }
    try:
        r = requests.get(API_URL, params=params, timeout=10)
        data = r.json()
        if "data" in data:
            row = data["data"][0]
            return {"time": row["t"], "water_level": float(row["v"]) }
        else:
            # Dòng này sẽ in ra lỗi cụ thể nếu vẫn còn trục trặc
            print(f"Water Level API Error: {data}")
    except Exception as e:
        print(f"Water Level Request Error: {e}")
    return None
# ==============================
# FETCH WIND
# ==============================
def fetch_wind():
    params = {
        "product": "wind",
        "station": STATION_WATER_WIND,
        "date": "latest",
        "units": "metric",
        "time_zone": "gmt",
        "format": "json"
    }
    try:
        r = requests.get(API_URL, params=params, timeout=10)
        data = r.json()
        if "data" in data:
            row = data["data"][0]
            return {"wind_speed": float(row["s"]), "wind_dir": float(row["d"]) }
    except Exception as e:
        print(f"Wind Request Error: {e}")
    return None

# ==============================
# FETCH CURRENT - Trạm s06010
# ==============================
def fetch_current():
    params = {
        "product": "currents",
        "station": STATION_CURRENT,
        "date": "latest",
        "units": "metric",
        "time_zone": "gmt",
        "format": "json"
    }
    try:
        r = requests.get(API_URL, params=params, timeout=10)
        data = r.json()
        if "data" in data:
            row = data["data"][0]
            # Chuyển cm/s -> m/s để đồng bộ với gió
            return {"current_speed": float(row["s"]) / 100, "current_dir": float(row["d"]) }
    except Exception as e:
        print(f"Current Request Error: {e}")
    return {"current_speed": 0.0, "current_dir": 0.0}

# ==============================
# FETCH ALL DATA
# ==============================

def fetch_all():
    sea = fetch_water_level()
    wind = fetch_wind()
    current = fetch_current()

    if sea is None or wind is None:
        print("Missing critical data from fetch_all")
        return None

    row = {**sea, **wind, **current}

    df = pd.DataFrame([row])

    df["time"] = pd.to_datetime(df["time"])

    return df

# ==============================
# PIPELINE - Hợp nhất dữ liệu
# ==============================
def run_pipeline():
    new = fetch_all() # Lấy dữ liệu THẬT hiện tại
    if new is None: return

    save_data(new)
    df = load_dataset()

    if df.empty or len(df) < 15:
        print(f"--- Đang thu thập dữ liệu ({len(df)}/15) ---")
        return

    # 1. Train model với cơ chế "nhìn về tương lai"
    model, df_train = train_model(df)

    if model:
        # 2. THỰC HIỆN DỰ ĐOÁN CHO 30 PHÚT TỚI
        # Lấy thông số gió và dòng chảy VỪA MỚI lấy được
        current_features = [[new["wind_speed"].iloc[0], new["current_speed"].iloc[0]]]

        # AI đoán mực nước cho 30 phút sau dựa trên gió/dòng chảy bây giờ
        future_prediction = model.predict(current_features)[0]
        current_actual = new["water_level"].iloc[0]

        print(f"\n" + "="*40)
        print(f" THỜI ĐIỂM HIỆN TẠI: {new['time'].iloc[0]}")
        print(f"   Mực nước thực tế : {current_actual:.3f} m")
        print(f"   Gió: {new['wind_speed'].iloc[0]} m/s | Dòng chảy: {new['current_speed'].iloc[0]} m/s")
        print(f"----------------------------------------")
        print(f" DỰ BÁO CHO 30 PHÚT TỚI:")
        print(f"   Mực nước dự kiến : {future_prediction:.3f} m")
        print(f"   Xu hướng: {'TĂNG' if future_prediction > current_actual else 'GIẢM'}")
        print("="*40 + "\n")

        # Vẽ biểu đồ
        plot_all(df)

def save_data(df):
    if df is None: # Added check for None DataFrame
        return
    if os.path.exists(DATA_FILE):
        old_df = pd.read_csv(DATA_FILE)
        df = pd.concat([old_df, df]).drop_duplicates(subset=["time"])
    df.to_csv(DATA_FILE, index=False)
    print("Dataset updated on disk.")

def load_dataset():
    if not os.path.exists(DATA_FILE): return pd.DataFrame()
    df = pd.read_csv(DATA_FILE)
    df["time"] = pd.to_datetime(df["time"])
    return df

def train_model(df):
    # Lấy 15-20 điểm dữ liệu để dự đoán có ý nghĩa
    if len(df) < 15:
        return None, None

    # Tạo mục tiêu: Mực nước của 30 phút sau
    df_train = df.copy()
    df_train['target_water_level'] = df_train['water_level'].shift(-5)

    train_data = df_train.dropna(subset=['target_water_level'])

    X = train_data[["wind_speed", "current_speed"]]
    y = train_data["target_water_level"]

    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X, y)

    return model, df_train

def plot_all(df):
    plt.close('all') # Đóng các hình cũ để tránh tràn bộ nhớ
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))--

    # Sea Level
    axes[0,0].plot(df["time"], df["water_level"], color='blue')
    axes[0,0].set_title("Sea Level Over Time")

    # Wind vs Sea
    axes[0,1].scatter(df["wind_speed"], df["water_level"], alpha=0.5)
    axes[0,1].set_title("Wind Speed vs Sea Level")

    # Current vs Sea
    axes[1,0].scatter(df["current_speed"], df["water_level"], color='green', alpha=0.5)
    axes[1,0].set_title("Current Speed vs Sea Level")

    # Trend
    axes[1,1].plot(df["time"].tail(20), df["water_level"].tail(20), marker='o')
    axes[1,1].set_title("Recent Trend (Last 20 pts)")

    plt.tight_layout()
    plt.pause(0.1) # Hiển thị biểu đồ mà không làm treo vòng lặp
    plt.show(block=False)

if __name__ == "__main__":
    while True:
        run_pipeline()
        print(f"\nWaiting {UPDATE_INTERVAL}s for next update...")
        time.sleep(UPDATE_INTERVAL)
# Out:
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (1/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (2/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (3/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (4/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (5/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (6/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (7/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (8/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (9/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (10/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (11/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (12/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (13/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
# --- Đang thu thập dữ liệu (14/15) ---
#
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:06:00
#    Mực nước thực tế : 1.147 m
#    Gió: 1.3 m/s | Dòng chảy: 0.397 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.080 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:12:00
#    Mực nước thực tế : 1.177 m
#    Gió: 1.0 m/s | Dòng chảy: 0.293 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.137 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:18:00
#    Mực nước thực tế : 1.206 m
#    Gió: 1.3 m/s | Dòng chảy: 0.139 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.178 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:24:00
#    Mực nước thực tế : 1.240 m
#    Gió: 1.4 m/s | Dòng chảy: 0.163 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.218 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:30:00
#    Mực nước thực tế : 1.270 m
#    Gió: 0.8 m/s | Dòng chảy: 0.098 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.197 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:36:00
#    Mực nước thực tế : 1.307 m
#    Gió: 1.3 m/s | Dòng chảy: 0.08900000000000001 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.282 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:42:00
#    Mực nước thực tế : 1.334 m
#    Gió: 1.7 m/s | Dòng chảy: 0.19699999999999998 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.295 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:48:00
#    Mực nước thực tế : 1.362 m
#    Gió: 1.1 m/s | Dòng chảy: 0.075 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.339 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 17:54:00
#    Mực nước thực tế : 1.394 m
#    Gió: 1.3 m/s | Dòng chảy: 0.048 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.350 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:00:00
#    Mực nước thực tế : 1.416 m
#    Gió: 1.2 m/s | Dòng chảy: 0.171 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.371 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:06:00
#    Mực nước thực tế : 1.441 m
#    Gió: 2.0 m/s | Dòng chảy: 0.024 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.415 m
#    Xu hướng: GIẢM
# ========================================
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:12:00
#    Mực nước thực tế : 1.467 m
#    Gió: 1.8 m/s | Dòng chảy: 0.11800000000000001 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.431 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:18:00
#    Mực nước thực tế : 1.487 m
#    Gió: 2.3 m/s | Dòng chảy: 0.171 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.427 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:24:00
#    Mực nước thực tế : 1.511 m
#    Gió: 2.0 m/s | Dòng chảy: 0.397 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.282 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:30:00
#    Mực nước thực tế : 1.538 m
#    Gió: 1.1 m/s | Dòng chảy: 0.561 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.220 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:36:00
#    Mực nước thực tế : 1.566 m
#    Gió: 0.8 m/s | Dòng chảy: 0.698 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.147 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:42:00
#    Mực nước thực tế : 1.586 m
#    Gió: 1.6 m/s | Dòng chảy: 0.741 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.123 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:48:00
#    Mực nước thực tế : 1.605 m
#    Gió: 0.8 m/s | Dòng chảy: 0.7509999999999999 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.105 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 18:54:00
#    Mực nước thực tế : 1.629 m
#    Gió: 0.6 m/s | Dòng chảy: 0.773 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.066 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 19:00:00
#    Mực nước thực tế : 1.645 m
#    Gió: 0.9 m/s | Dòng chảy: 0.743 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.154 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...
# Dataset updated on disk.
#
# ========================================
#  THỜI ĐIỂM HIỆN TẠI: 2026-03-19 19:06:00
#    Mực nước thực tế : 1.653 m
#    Gió: 1.1 m/s | Dòng chảy: 0.731 m/s
# ----------------------------------------
#  DỰ BÁO CHO 30 PHÚT TỚI:
#    Mực nước dự kiến : 1.399 m
#    Xu hướng: GIẢM
# ========================================
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# Waiting 360s for next update...

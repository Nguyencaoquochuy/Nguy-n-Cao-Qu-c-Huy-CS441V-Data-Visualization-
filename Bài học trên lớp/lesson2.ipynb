# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import matplotlib.pyplot as plt

# %%
# install xlrd
# !pip install xlrd

print('xlrd installed!')
# Out:
# ...
# xlrd installed!

# %%
raw_data = pd.read_excel('http://s3.hothienlac.com/yomitoon/Canada.xlsx',
                       sheet_name='Canada by Citizenship',
                       skiprows=range(20),
                      )

# %%
raw_data
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2004    2005  \
# 0      Southern Asia  902  Developing regions      16  ...    2978    3436
# ...

# %%
# print the dimensions of the dataframe
print(raw_data.shape)
# Out:
# (197, 43)

# %%
dropped_data = raw_data.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1,)

# let's view the first five elements and see how the dataframe was changed
dropped_data
# Out:
#              OdName AreaName          RegName             DevName    1980  \
# 0       Afghanistan     Asia    Southern Asia  Developing regions      16
# 1           Albania   Europe  Southern Europe   Developed regions       1
# 2           Algeria   Africa  Northern Africa  Developing regions      80
# 3    American Samoa  Oceania        Polynesia  Developing regions       0
# 4           Andorra   Europe  Southern Europe   Developed regions       0
# ..              ...      ...              ...                 ...     ...
# 192           Yemen     Asia     Western Asia  Developing regions       1
# 193          Zambia   Africa   Eastern Africa  Developing regions      11
# 194        Zimbabwe   Africa   Eastern Africa  Developing regions      72
# 195         Unknown    World            World               World   44000
# 196           Total    World            World               World  143137
#
#        1981    1982   1983   1984   1985  ...    2004    2005    2006    2007  \
# ...

# %%
rename_data = dropped_data.rename(columns={'OdName':'Country', 'AreaName':'Continent','RegName':'Region'})

# let's view the first five elements and see how the dataframe was changed
rename_data
# Out:
#             Country Continent           Region             DevName    1980  \
# 0       Afghanistan      Asia    Southern Asia  Developing regions      16
# 1           Albania    Europe  Southern Europe   Developed regions       1
# 2           Algeria    Africa  Northern Africa  Developing regions      80
# 3    American Samoa   Oceania        Polynesia  Developing regions       0
# 4           Andorra    Europe  Southern Europe   Developed regions       0
# ..              ...       ...              ...                 ...     ...
# 192           Yemen      Asia     Western Asia  Developing regions       1
# 193          Zambia    Africa   Eastern Africa  Developing regions      11
# 194        Zimbabwe    Africa   Eastern Africa  Developing regions      72
# 195         Unknown     World            World               World   44000
# 196           Total     World            World               World  143137
#
# ...

# %%
all(isinstance(column, str) for column in rename_data.columns)
# Out:
# False

# %%
rename_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 38 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    197 non-null    object
#  1   Continent  197 non-null    object
#  2   Region     197 non-null    object
#  3   DevName    197 non-null    object
#  4   1980       197 non-null    int64
#  5   1981       197 non-null    int64
#  6   1982       197 non-null    int64
#  7   1983       197 non-null    int64
#  8   1984       197 non-null    int64
#  9   1985       197 non-null    int64
#  10  1986       197 non-null    int64
#  11  1987       197 non-null    int64
#  12  1988       197 non-null    int64
#  13  1989       197 non-null    int64
#  14  1990       197 non-null    int64
#  15  1991       197 non-null    int64
#  16  1992       197 non-null    int64
#  17  1993       197 non-null    int64
#  18  1994       197 non-null    int64
#  19  1995       197 non-null    int64
# ...

# %%
rename_data.columns = list(map(str, rename_data.columns))
all(isinstance(column, str) for column in rename_data.columns)
# Out:
# True

# %%
rename_data.columns
# Out:
# Index(['Country', 'Continent', 'Region', 'DevName', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
data = rename_data.set_index("Country")
data
# Out:
#                Continent           Region             DevName    1980    1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions      16      39
# Albania           Europe  Southern Europe   Developed regions       1       0
# Algeria           Africa  Northern Africa  Developing regions      80      67
# American Samoa   Oceania        Polynesia  Developing regions       0       1
# Andorra           Europe  Southern Europe   Developed regions       0       0
# ...                  ...              ...                 ...     ...     ...
# Yemen               Asia     Western Asia  Developing regions       1       2
# Zambia            Africa   Eastern Africa  Developing regions      11      17
# Zimbabwe          Africa   Eastern Africa  Developing regions      72     114
# Unknown            World            World               World   44000   18078
# Total              World            World               World  143137  128641
#
# ...

# %%
year = list(map(str, range(1980, 2014)))
year
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
data['Total'] = data[year].sum(axis=1)
data
# Out:
#                Continent           Region             DevName    1980    1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions      16      39
# Albania           Europe  Southern Europe   Developed regions       1       0
# Algeria           Africa  Northern Africa  Developing regions      80      67
# American Samoa   Oceania        Polynesia  Developing regions       0       1
# Andorra           Europe  Southern Europe   Developed regions       0       0
# ...                  ...              ...                 ...     ...     ...
# Yemen               Asia     Western Asia  Developing regions       1       2
# Zambia            Africa   Eastern Africa  Developing regions      11      17
# Zimbabwe          Africa   Eastern Africa  Developing regions      72     114
# Unknown            World            World               World   44000   18078
# Total              World            World               World  143137  128641
#
# ...

# %%
top5 = data.sort_values(by='Total', ascending=False).drop(index=['Total','Unknown'])
top5.head(5)
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
# % total cua 5 nupoc
top5.sum(axis=0)
# Out:
# Continent    AsiaAsiaEuropeAsiaAsiaNorthern AmericaAsiaAsia...
# Region       Southern AsiaEastern AsiaNorthern EuropeSouth-...
# DevName      Developing regionsDeveloping regionsDeveloped ...
# 1980                                                     99137
# 1981                                                    110563
# 1982                                                    104271
# 1983                                                     75550
# 1984                                                     73417
# 1985                                                     69978
# 1986                                                     86048
# 1987                                                    134771
# 1988                                                    139306
# 1989                                                    164432
# 1990                                                    188054
# 1991                                                    207509
# ...

# %%
top5['Total'] = top5[year].sum(axis = 1)
top5
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
# ...                                                      ...
# New Caledonia                                        Oceania
# San Marino                                            Europe
# Marshall Islands                                     Oceania
# Western Sahara                                        Africa
# Palau                                                Oceania
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
df_2013 = data[['2013']]
df_2013
# Out:
#                   2013
# Country
# Afghanistan       2004
# Albania            603
# Algeria           4331
# American Samoa       0
# Andorra              1
# ...                ...
# Yemen              217
# Zambia              59
# Zimbabwe           407
# Unknown           1484
# Total           259021
#
# [197 rows x 1 columns]

# %%
rang = np.histogram(df_2013, bins = 20)[1]

# %%
[rang[i+1] - rang[i] for i in range(len(rang)-1)]
# Out:
# [np.float64(12951.05),
#  np.float64(12951.05),
#  np.float64(12951.049999999996),
#  np.float64(12951.050000000003),
#  np.float64(12951.050000000003),
#  np.float64(12951.049999999988),
#  np.float64(12951.050000000003),
#  np.float64(12951.050000000003),
#  np.float64(12951.050000000003),
#  np.float64(12951.050000000003),
#  np.float64(12951.049999999988),
#  np.float64(12951.049999999988),
#  np.float64(12951.050000000017),
#  np.float64(12951.049999999988),
#  np.float64(12951.050000000017),
#  np.float64(12951.049999999988),
#  np.float64(12951.049999999988),
#  np.float64(12951.050000000017),
#  np.float64(12951.049999999988),
#  np.float64(12951.050000000017)]

# %%
df_2013['2013'].plot(kind='hist', figsize=(8, 5), bins = 10)

plt.title('Histogram of Immigration from 195 countries in 2013') # add a title to the histogram
plt.ylabel('Number of Countries') # add y-label
plt.xlabel('Number of Immigrants') # add x-label

plt.show()

# %%
df_dnf = data.loc[['Denmark', 'Norway', 'Sweden'], year].T
df_dnf
# Out:
# Country  Denmark  Norway  Sweden
# 1980         272     116     281
# 1981         293      77     308
# 1982         299     106     222
# 1983         106      51     176
# 1984          93      31     128
# 1985          73      54     158
# 1986          93      56     187
# 1987         109      80     198
# 1988         129      73     171
# 1989         129      76     182
# 1990         118      83     130
# 1991         111     103     167
# 1992         158      74     179
# 1993         186      92     203
# 1994          93      60     192
# 1995         111      65     176
# 1996          70      70     161
# 1997          83     104     151
# 1998          63      31     123
# 1999          81      36     170
# 2000          93      56     138
# 2001          81      78     184
# 2002          70      74     149
# 2003          89      77     161
# 2004          89      73     129
# 2005          62      57     205
# 2006         101      53     139
# ...

# %%
# let's get the x-tick values
count, bin_edges = np.histogram(df_dnf, 20)

# un-stacked histogram
df_dnf.plot(kind ='hist',
          figsize=(10, 6),
          bins=20,
          alpha=0.6,
          xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen']
         )

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
df_ct = data.loc[['Greece', 'Albania', 'Bulgaria'], year].T
df_ct
# Out:
# Country  Greece  Albania  Bulgaria
# 1980       1065        1        24
# 1981        953        0        20
# 1982        897        0        12
# 1983        633        0        33
# 1984        580        0        11
# 1985        584        0        24
# 1986        547        1        33
# 1987        765        2        52
# 1988        564        2        43
# 1989        773        3        85
# 1990        538        3       172
# 1991        592       21       611
# 1992        492       56      1116
# 1993        445       96       965
# 1994        275       71       687
# 1995        220       63       762
# 1996        221      113       825
# 1997        190      307       732
# 1998        141      574       779
# 1999        149     1264       832
# 2000        150     1816      1172
# 2001        135     1602      1283
# 2002        107     1021      1517
# 2003        117      853      1507
# 2004        120     1450      2022
# 2005        100     1223      1738
# ...

# %%
# let's get the x-tick values
count, bin_edges = np.histogram(df_ct, 15)

# un-stacked histogram
df_ct.plot(kind ='hist',
          figsize=(10, 6),
          bins=15,
          alpha=0.7,
          xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen']
         )

plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
plt.ylabel('Number of Years')
plt.xlabel('Number of Immigrants')

plt.show()

# %%
def histogram(df : pd.DataFrame, contries : list[str], quanlity : int) -> None:
    count, bin_edges = np.histogram(df, quanlity)
    df.loc[contries, year].plot(kind ='hist',
          figsize=(10, 6),
          bins=quanlity,
          alpha=0.7,
          xticks=bin_edges,
          stacked = True
    )

    plt.title('Histogram of Immigration from Denmark, Norway, and Sweden from 1980 - 2013')
    plt.ylabel('Number of Years')
    plt.xlabel('Number of Immigrants')

    plt.show()

# %%
# histogram(data.loc['Greece', 'Albania', 'Bulgaria'], 15)

# %%
# step 1: get the data
df_iceland = data.loc['Iceland', year]
df_iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
# step 2: plot data
df_iceland.plot(kind='bar', figsize=(10, 6))

plt.xlabel('Year') # add to x-label to the plot
plt.ylabel('Number of immigrants') # add y-label to the plot
plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

plt.show()

# %%
df_iceland.plot(kind='bar', figsize=(10, 6), rot=90) # rotate the bars by 90 degrees

plt.xlabel('Year')
plt.ylabel('Number of Immigrants')
plt.title('Icelandic Immigrants to Canada from 1980 to 2013')

# Annotate arrow
plt.annotate('',                      # s: str. Will leave it blank for no text
             xy=(32, 70),             # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),         # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',         # will use the coordinate system of the object being annotated
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
            )

# Annotate Text
plt.annotate('2008 - 2011 Financial Crisis', # text to display
             xy=(28, 30),                    # start the text at at point (year 2008 , pop 30)
             rotation=72.5,                  # based on trial and error to match the arrow
             va='bottom',                    # want the text to be vertically 'bottom' aligned
             ha='left',                      # want the text to be horizontally 'left' algned.
            )

plt.show()
